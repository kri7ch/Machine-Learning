# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rakhm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rakhm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rakhm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
pip install pymorphy3
# Out:
# Requirement already satisfied: pymorphy3 in c:\users\rakhm\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: dawg2-python>=0.8.0 in c:\users\rakhm\anaconda3\lib\site-packages (from pymorphy3) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\rakhm\anaconda3\lib\site-packages (from pymorphy3) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in c:\users\rakhm\anaconda3\lib\site-packages (from pymorphy3) (69.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import string
import re
import nltk
import pymorphy3

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %%
df_habr = pd.read_csv("habr.csv")

# %%
df_habr.head(10)
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Нулевой байт как помощник в исследованиях уязв...
# 1           1  Вышла «Альт Рабочая станция» 11.0 с новой граф...
# 2           2  HTML и CSS ошибки, влияющие на доступность. Мо...
# 3           3  Релиз WB-Cloud On-Premise, Алиса из коробки и ...
# 4           4  Всё ради игрока: как ИИ в играх хитрит, чтобы ...
# 5           5  Цифра, пленка и советские объективы: как я увл...
# 6           6  Дела сердечные: предотвращение сердечной недос...
# 7           7  Хроники архитектурного дизайна. Часть 3: конце...
# 8           8            Обзор серверного ИБП Ippon Pacific 2000
# 9           9  Потратить нельзя сэкономить. Дилемма затрат на...
#
#           namecompany                                        description  \
# 0             Cloud4Y                #1 Корпоративный облачный провайдер
# 1         Базальт СПО                                           Компания
# 2           RUVDS.com         VDS/VPS-хостинг. Скидка 15% по коду HABR15
# 3         Wiren Board       Оборудование для автоматизации и мониторинга
# 4         Serverspace  IT-инфраструктура | Удвоение платежа по коду HABR
# 5                 МТС                          Про жизнь и развитие в IT
# 6  ua-hosting.company      Хостинг-провайдер: серверы в NL до 300 Гбит/с
# 7             Usetech                          Международная IT-компания
# 8                e2e4                                           Компания
# 9          Ростелеком      Крупнейший провайдер цифровых услуг и решений
#
#    rating                                              field        date  \
# 0       0  Связь и телекоммуникации, Домены и хостинг, Ве...  2025-04-30
# 1       0                            Программное обеспечение  2025-04-30
# 2       0  Связь и телекоммуникации, Домены и хостинг, Ве...  2025-04-30
# 3       0  Программное обеспечение, Аппаратное обеспечени...  2025-04-30
# 4       0                                   Домены и хостинг  2025-04-30
# 5       0  Связь и телекоммуникации, Мобильные технологии...  2025-04-30
# 6       0  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-30
# 7       0  Программное обеспечение, Дизайн и юзабилити, М...  2025-04-30
# 8       0  Программное обеспечение, Аппаратное обеспечени...  2025-04-30
# 9       0  Программное обеспечение, Связь и телекоммуника...  2025-04-30
#
#                                              textpub
# 0  Это статья пентестера 0xold, который 8 месяцев...
# 1   «Базальт СПО» выпустила операционную систему ...
# 2    Хабр, я снова пришёл к вам с практическими с...
# 3  На WBCE 2025 Александр Дегтярев, руководитель ...
# 4  В играх ИИ редко играет по правилам. И это — к...
# 5  Привет, Хабр! Меня зовут Павел Шестаков. В МТС...
# 6    Организм человека — это совокупность систем,...
# 7  Роман РемизовСистемный аналитик ГК ЮзтехПривет...
# 8  Это второй обзор серверного ИБП нашего автора ...
# 9  Однажды мне пришлось испытать на себе последст...
